# %%
import mirosheet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6680/1436757299.py in <module>
# ----> 1 import mirosheet
#
# ModuleNotFoundError: No module named 'mirosheet'

# %%
import mitosheet

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-7d8ce28a-8f99-4306-bfd2-a2c39eb2179c", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-7d8ce28a-8f99-4306-bfd2-a2c39eb2179c') # Let Mito know which analysis is being run

# Imported /home/dev/Downloads/School Subjects.xlsx
import pandas as pd
sheet_df_dictonary = pd.read_excel('/home/dev/Downloads/School Subjects.xlsx', sheet_name=['Sheet1'], skiprows=0)
Sheet1 = sheet_df_dictonary['Sheet1']

# Filtered name in Sheet1
Sheet1 = Sheet1[Sheet1['name'].str.contains('Language', na=False)]

# Renamed name to Subject in Sheet1
Sheet1.rename(columns={"name": "Subject"}, inplace=True)

  
# MITO CODE END (DO NOT EDIT)
# Out:
# /home/dev/PycharmProjects/Bank_File_Generator/venv/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# Backing off send_request(...) for 0.7s (requests.exceptions.ConnectionError: HTTPSConnectionPool(host='api.segment.io', port=443): Max retries exceeded with url: /v1/batch (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f1bd7581e20>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')))
# ...

# %%
Sheet1
# Out:
#                                  Subject      docID
# 0                Afrikaans Home Language  3304492.0
# 1    Afrikaans First Additional Language  3314522.0
# 2   Afrikaans Second Additional Language  3354552.0
# 3                  English Home Language  3304582.0
# 4      English First Additional Language  3314612.0
# ..                                   ...        ...
# 77      Telegu First Additional Language  3352632.0
# 78     Telegu Second Additional Language  3352662.0
# 79                    Urdu Home Language  3352692.0
# 80        Urdu First Additional Language  3352722.0
# 81       Urdu Second Additional Language  3352752.0
#
# [62 rows x 2 columns]

# %%
Sheet1 = Sheet1[['docID','Subject']]

# %%
Sheet1
# Out:
#         docID                               Subject
# 0   3304492.0               Afrikaans Home Language
# 1   3314522.0   Afrikaans First Additional Language
# 2   3354552.0  Afrikaans Second Additional Language
# 3   3304582.0                 English Home Language
# 4   3314612.0     English First Additional Language
# ..        ...                                   ...
# 77  3352632.0      Telegu First Additional Language
# 78  3352662.0     Telegu Second Additional Language
# 79  3352692.0                    Urdu Home Language
# 80  3352722.0        Urdu First Additional Language
# 81  3352752.0       Urdu Second Additional Language
#
# [62 rows x 2 columns]
